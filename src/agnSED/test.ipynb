# %%
import agnSED
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import agnSED
#
# File ~/adaf/release/paper_release/agnSED/src/agnSED/agnSED.py:2
#       1 import numpy as np
# ----> 2 from .setUp import *
#       3 from .utils import *
#       6 def SED(logm, logmdot, k0=0, k1=len(lognu)-1, truncation=True):
#
# ImportError: attempted relative import with no known parent package
